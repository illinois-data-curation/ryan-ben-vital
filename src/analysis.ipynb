# %%
import pandas as pd
import hmac
import hashlib
import requests
from io import StringIO

# %%
with open('../checksums.txt', 'rb') as f:
    data = f.read()
    checksum_verify = str(data.split()[1]).split("'")[1]

url = 'https://www.ncei.noaa.gov/access/monitoring/climate-at-a-glance/statewide/time-series/13/pcp/1/9/1895-2024.csv?base_prd=true&begbaseyear=1901&endbaseyear=2000'
response = requests.get(url)
checksum = hashlib.sha256(response.text.encode('utf-8')).hexdigest()

if checksum == checksum_verify:
    print('Checksum verification passed.\n')
    df_ncei = pd.read_csv(StringIO(response.text), skiprows=4)
    print(df_ncei.head())

else:
   print('Checksum verification failed.')
# Out:
# Checksum verification passed.
#
#      Date  Value  Anomaly
# 0  189509   3.12    -0.55
# 1  189609   3.97     0.30
# 2  189709   1.97    -1.70
# 3  189809   2.62    -1.05
# 4  189909   0.96    -2.71

# %%
with open('../checksums.txt', 'rb') as f:
    data = f.read()
    checksum_verify = str(data.split()[3]).split("'")[1]

endpoint = 'https://data.iowa.gov/resource/tw78-ziwj.csv?$limit=583174'
response = requests.get(endpoint)
checksum = hashlib.sha256(response.text.encode('utf-8')).hexdigest()

if checksum == checksum_verify:
    print('Checksum verification passed.\n')
    df_accidents = pd.read_csv(StringIO(response.text))
    print(df_accidents.head())

else:
   print('Checksum verification failed.')
# Out:
# Checksum verification failed.

# %%
# cleaning df_accidents

## converting `date_of_crash` to `year` 
date_time = pd.to_datetime(df_accidents['date_of_crash'])
df_accidents['year'] = date_time.dt.year

## narrowing `df_accidents` to contain only our columns of interest
df_accidents = df_accidents[[
    'year', 'enviro_conditions', 'surface_conditions', 'weather_conditions',
    'crash_severity', 'fatalities', 'injuries', 'majinjury', 'mininjury',
    'possinjury', 'unkinjury', 'propdmg'
]]

# %%
print(df_accidents['enviro_conditions'].unique())
print(df_accidents['weather_conditions'].unique())
print(df_accidents['surface_conditions'].unique())
print(df_accidents['crash_severity'].unique())
# Out:
# [nan 'None apparent' 'Unknown' 'Weather conditions' 'Animal in roadway'
#  'Glare' 'Other (explain in narrative)' 'Visual obstruction'
#  'Non-motorist action' 'Severe crosswind']
# ['Cloudy' 'Snow' 'Clear' 'Unknown' nan 'Rain'
#  'Other (explain in narrative)' 'Sleet, hail' 'Blowing sand, soil, dirt'
#  'Severe winds' 'Fog, smoke, smog' 'Freezing rain/drizzle' 'Blowing snow']
# ['Snow' 'Ice/frost' 'Slush' 'Wet' 'Dry' 'Other (explain in narrative)' nan
#  'Unknown' 'Mud, dirt' 'Water (standing or moving)' 'Gravel' 'Sand' 'Oil']
# ['Minor Injury' 'Property Damage Only' 'Possible/Unknown' 'Major Injury'
#  'Fatal']

# %%
df_accidents['enviro_conditions'].isna().value_counts()
# Out:
# enviro_conditions
# False    436991
# True     146183
# Name: count, dtype: int64

# %%
df_accidents['enviro_conditions'] = df_accidents['enviro_conditions'].fillna('Unknown')
df_accidents['surface_conditions'] = df_accidents['surface_conditions'].fillna('Unknown')

# %% [markdown]
# ## Want to make sure we get `Rain`,`Sleet, hail`,`Freezing rain/drizzle` within `weather_conditions`

# %% [markdown]
# ## Want to make sure we get `Wet` within `surface_conditions`

# %%
filtered_test = df_accidents[((df_accidents['weather_conditions'] == 'Rain') | (df_accidents['weather_conditions'] == 'Sleet, hail') | (df_accidents['weather_conditions'] == 'Freezing rain/drizzle')) & ((df_accidents['surface_conditions'] == 'Wet') | (df_accidents['surface_conditions'] == 'Unknown'))]
filtered_test.sample(10)
# Out:
#         year   enviro_conditions surface_conditions weather_conditions  \
# 174937  2017       None apparent                Wet               Rain
# 193298  2017  Weather conditions                Wet               Rain
# 107403  2016       None apparent                Wet               Rain
# 155455  2016       None apparent                Wet               Rain
# 186175  2017  Weather conditions                Wet               Rain
# 244639  2018  Weather conditions                Wet               Rain
# 50796   2014             Unknown                Wet               Rain
# 295357  2019       None apparent                Wet               Rain
# 23555   2014             Unknown                Wet               Rain
# 292576  2019       None apparent                Wet               Rain
#
#               crash_severity  fatalities  injuries  majinjury  mininjury  \
# 174937      Possible/Unknown           0         1          0          0
# 193298  Property Damage Only           0         0          0          0
# 107403  Property Damage Only           0         0          0          0
# 155455  Property Damage Only           0         0          0          0
# 186175      Possible/Unknown           0         1          0          0
# 244639  Property Damage Only           0         0          0          0
# 50796   Property Damage Only           0         0          0          0
# 295357  Property Damage Only           0         0          0          0
# 23555   Property Damage Only           0         0          0          0
# 292576  Property Damage Only           0         0          0          0
#
#         possinjury  unkinjury  propdmg
# 174937           1          0     3000
# 193298           0          0     9300
# 107403           0          0     1700
# 155455           0          0     3500
# 186175           1          0    50000
# 244639           0          0    15000
# 50796            0          0     4500
# 295357           0          0    16200
# 23555            0          0     3000
# 292576           0          0     3000

# %%
df_ncei.head(5)
# Out:
#      Date  Value  Anomaly
# 0  189509   3.12    -0.55
# 1  189609   3.97     0.30
# 2  189709   1.97    -1.70
# 3  189809   2.62    -1.05
# 4  189909   0.96    -2.71

# %%
## cleaning df_ncei

df_ncei['year'] = df_ncei['Date'].apply(lambda x: int(str(x)[:4]))
df_ncei.rename(columns={'Value':'precipitation'}, inplace=True)
df_ncei = df_ncei[['year', 'precipitation']]
df_ncei['year'] = df_ncei['year'].astype(int)
df_ncei = df_ncei[df_ncei['year'] >= 2014]
df_ncei.head()
# Out:
#      year  precipitation
# 119  2014           4.35
# 120  2015           4.18
# 121  2016           6.12
# 122  2017           2.31
# 123  2018           8.10

# %%
grouped_df = filtered_test.groupby(['year', 'enviro_conditions', 'surface_conditions', 'weather_conditions', 'crash_severity']).sum().reset_index()
grouped_df
# Out:
#      year   enviro_conditions surface_conditions weather_conditions  \
# 0    2014             Unknown            Unknown               Rain
# 1    2014             Unknown            Unknown               Rain
# 2    2014             Unknown            Unknown        Sleet, hail
# 3    2014             Unknown                Wet               Rain
# 4    2014             Unknown                Wet               Rain
# ..    ...                 ...                ...                ...
# 463  2024  Weather conditions                Wet               Rain
# 464  2024  Weather conditions                Wet               Rain
# 465  2024  Weather conditions                Wet               Rain
# 466  2024  Weather conditions                Wet        Sleet, hail
# 467  2024  Weather conditions                Wet        Sleet, hail
#
#            crash_severity  fatalities  injuries  majinjury  mininjury  \
# 0        Possible/Unknown           0         3          0          0
# 1    Property Damage Only           0         0          0          0
# 2        Possible/Unknown           0         1          0          0
# 3                   Fatal          19        21          5          9
# 4            Major Injury           0       114         81         23
# ..                    ...         ...       ...        ...        ...
# 463          Minor Injury           0        54          0         44
# 464      Possible/Unknown           0        85          0          0
# 465  Property Damage Only           0         0          0          0
# 466      Possible/Unknown           0         1          0          0
# 467  Property Damage Only           0         0          0          0
#
#      possinjury  unkinjury  propdmg
# 0             3          0     6300
# 1             0          0    24300
# 2             1          0    11500
# 3             7          0   365500
# 4            10          0   903187
# ..          ...        ...      ...
# 463           8          2   496900
# 464          74         11   701358
# 465           0          0  2821177
# 466           1          0     3000
# 467           0          0    16200
#
# [468 rows x 12 columns]

# %%
yearly_counts = {'year': [], 'count': []}

current_year = None
count = 0

for index, row in filtered_test.iterrows():
    if row['year'] == current_year:
        count += 1
    else:
        if current_year is not None:
            yearly_counts['year'].append(current_year)
            yearly_counts['count'].append(count)
        current_year = row['year']
        count = 1

yearly_counts['year'].append(current_year)
yearly_counts['count'].append(count)

yearly_counts_df = pd.DataFrame(yearly_counts)
yearly_counts_df
# Out:
#     year  count
# 0   2014   3017
# 1   2015   3986
# 2   2016   2679
# 3   2017   3047
# 4   2018   3389
# 5   2019   3093
# 6   2020   2276
# 7   2021   2383
# 8   2022   2359
# 9   2023   2012
# 10  2024   1437

# %%
grouped_df.head(10)
# Out:
#    year enviro_conditions surface_conditions weather_conditions  \
# 0  2014           Unknown            Unknown               Rain
# 1  2014           Unknown            Unknown               Rain
# 2  2014           Unknown            Unknown        Sleet, hail
# 3  2014           Unknown                Wet               Rain
# 4  2014           Unknown                Wet               Rain
# 5  2014           Unknown                Wet               Rain
# 6  2014           Unknown                Wet               Rain
# 7  2014           Unknown                Wet               Rain
# 8  2014           Unknown                Wet        Sleet, hail
# 9  2014           Unknown                Wet        Sleet, hail
#
#          crash_severity  fatalities  injuries  majinjury  mininjury  \
# 0      Possible/Unknown           0         3          0          0
# 1  Property Damage Only           0         0          0          0
# 2      Possible/Unknown           0         1          0          0
# 3                 Fatal          19        21          5          9
# 4          Major Injury           0       114         81         23
# 5          Minor Injury           0       398          0        337
# 6      Possible/Unknown           0       638          0          0
# 7  Property Damage Only           0         0          0          0
# 8          Major Injury           0         2          2          0
# 9          Minor Injury           0        11          0         10
#
#    possinjury  unkinjury   propdmg
# 0           3          0      6300
# 1           0          0     24300
# 2           1          0     11500
# 3           7          0    365500
# 4          10          0    903187
# 5          57          4   2653358
# 6         601         37   3752727
# 7           0          0  11380753
# 8           0          0     17200
# 9           0          1     79453

# %%
grouped_df_2 = filtered_test.groupby(['year']).sum().reset_index()
grouped_df_2
# Out:
#     year                                  enviro_conditions  \
# 0   2014  UnknownUnknownUnknownUnknownUnknownUnknownUnkn...
# 1   2015  UnknownUnknownUnknownUnknownUnknownUnknownUnkn...
# 2   2016  None apparentNone apparentNone apparentNone ap...
# 3   2017  Weather conditionsNone apparentNone apparentNo...
# 4   2018  None apparentNone apparentNone apparentWeather...
# 5   2019  None apparentWeather conditionsWeather conditi...
# 6   2020  Animal in roadwayNone apparentNone apparentNon...
# 7   2021  Weather conditionsWeather conditionsWeather co...
# 8   2022  None apparentWeather conditionsWeather conditi...
# 9   2023  Weather conditionsNone apparentNone apparentWe...
# 10  2024  None apparentNone apparentWeather conditionsNo...
#
#                                    surface_conditions  \
# 0   WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
# 1   WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
# 2   WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
# 3   WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
# 4   WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
# 5   WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
# 6   WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
# 7   WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
# 8   WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
# 9   WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
# 10  WetWetWetWetWetWetWetWetWetWetWetWetWetWetWetW...
#
#                                    weather_conditions  \
# 0   RainRainRainRainSleet, hailSleet, hailRainRain...
# 1   Freezing rain/drizzleFreezing rain/drizzleRain...
# 2   Freezing rain/drizzleFreezing rain/drizzleFree...
# 3   RainRainFreezing rain/drizzleFreezing rain/dri...
# 4   Freezing rain/drizzleFreezing rain/drizzleFree...
# 5   RainFreezing rain/drizzleRainRainRainRainRainR...
# 6   RainFreezing rain/drizzleRainRainRainFreezing ...
# 7   Freezing rain/drizzleFreezing rain/drizzleFree...
# 8   Freezing rain/drizzleFreezing rain/drizzleFree...
# 9   RainRainRainFreezing rain/drizzleRainRainRainR...
# 10  Freezing rain/drizzleRainFreezing rain/drizzle...
#
#                                        crash_severity  fatalities  injuries  \
# 0   Property Damage OnlyProperty Damage OnlyProper...          19      1191
# 1   Property Damage OnlyMinor InjuryProperty Damag...          23      1606
# 2   Possible/UnknownProperty Damage OnlyProperty D...           7      1013
# 3   Possible/UnknownMajor InjuryProperty Damage On...           9      1190
# 4   Property Damage OnlyProperty Damage OnlyProper...          12      1260
# 5   Property Damage OnlyProperty Damage OnlyProper...          18      1244
# 6   Property Damage OnlyPossible/UnknownProperty D...          17       845
# 7   Possible/UnknownPossible/UnknownProperty Damag...          11       975
# 8   Possible/UnknownProperty Damage OnlyPossible/U...          13       914
# 9   Minor InjuryProperty Damage OnlyPossible/Unkno...          11       765
# 10  Possible/UnknownProperty Damage OnlyProperty D...           9       522
#
#     majinjury  mininjury  possinjury  unkinjury   propdmg
# 0          88        379         682         42  19511105
# 1          71        460         966        109  26318128
# 2          46        277         611         79  17648125
# 3          69        327         692        102  20706389
# 4          51        357         743        109  22543154
# 5          66        355         728         95  21840047
# 6          47        232         472         94  17328310
# 7          41        299         539         96  19965911
# 8          62        285         469         98  20642149
# 9          37        263         383         82  18308339
# 10         29        157         272         64  13602049

# %%
merged_df = pd.merge(df_ncei, grouped_df_2, on='year', how='inner')
merged_df = pd.merge(yearly_counts_df, merged_df, on='year', how='inner')
merged_df = merged_df[['year','precipitation','count','fatalities','injuries','majinjury','mininjury','possinjury','unkinjury','propdmg']]
merged_df
# Out:
#     year  precipitation  count  fatalities  injuries  majinjury  mininjury  \
# 0   2014           4.35   3017          19      1191         88        379
# 1   2015           4.18   3986          23      1606         71        460
# 2   2016           6.12   2679           7      1013         46        277
# 3   2017           2.31   3047           9      1190         69        327
# 4   2018           8.10   3389          12      1260         51        357
# 5   2019           6.21   3093          18      1244         66        355
# 6   2020           4.07   2276          17       845         47        232
# 7   2021           1.81   2383          11       975         41        299
# 8   2022           1.90   2359          13       914         62        285
# 9   2023           2.14   2012          11       765         37        263
# 10  2024           0.69   1437           9       522         29        157
#
#     possinjury  unkinjury   propdmg
# 0          682         42  19511105
# 1          966        109  26318128
# 2          611         79  17648125
# 3          692        102  20706389
# 4          743        109  22543154
# 5          728         95  21840047
# 6          472         94  17328310
# 7          539         96  19965911
# 8          469         98  20642149
# 9          383         82  18308339
# 10         272         64  13602049

# %%
merged_df.to_csv('../data/processed/integrated.csv')
